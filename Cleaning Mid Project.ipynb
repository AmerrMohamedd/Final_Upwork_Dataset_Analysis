# %% [markdown]
# # Cleaning Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('D:/Courses/AI/Epsilon AI/Mid project(After Session 38)/Final_Upwork_Dataset.csv')
df
# Out:
#                                                Job Title  \
# 0                          Power bi specialist freelance
# 1                Case Study (on-demand delivery startup)
# 2      File Maker Pro Reports, Charts, Query and Ongo...
# 3              Implementation of EleutherAI/gpt-neox-20b
# 4      BI and Data Engineer for Upwork Finance System...
# ...                                                  ...
# 63945              (Commission Based) Cold Caller Needed
# 63946  High-Performance *Ecom Email* Copywriter Suppl...
# 63947                   TikTok profile managment Hungary
# 63948  Creating videos (including UGC) for TikTok - A...
# 63949                                                NaN
#
#                                                  Job_URL EX_level_demand  \
# 0      https://www.upwork.com/jobs/Power-specialist-f...          Expert
# 1      https://www.upwork.com/jobs/Case-Study-demand-...    Intermediate
# ...

# %%
df.head()
# Out:
#                                            Job Title  \
# 0                      Power bi specialist freelance
# 1            Case Study (on-demand delivery startup)
# 2  File Maker Pro Reports, Charts, Query and Ongo...
# 3          Implementation of EleutherAI/gpt-neox-20b
# 4  BI and Data Engineer for Upwork Finance System...
#
#                                              Job_URL EX_level_demand  \
# 0  https://www.upwork.com/jobs/Power-specialist-f...          Expert
# 1  https://www.upwork.com/jobs/Case-Study-demand-...    Intermediate
# 2  https://www.upwork.com/jobs/File-Maker-Pro-Rep...    Intermediate
# 3  https://www.upwork.com/jobs/Implementation-Ele...          Expert
# 4  https://www.upwork.com/jobs/and-span-Data-span...          Expert
#
#                         Time_Limitation Search_Keyword     Posted_from  \
# 0                                   NaN   Data_science   5 minutes ago
# 1                                   NaN   Data_science   5 minutes ago
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63950 entries, 0 to 63949
# Data columns (total 41 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Job Title             63949 non-null  object
#  1   Job_URL               63949 non-null  object
#  2   EX_level_demand       56935 non-null  object
#  3   Time_Limitation       23034 non-null  object
#  4   Search_Keyword        63949 non-null  object
#  5   Posted_from           63913 non-null  object
#  6   Description           63948 non-null  object
#  7   Category1_URL_search  63505 non-null  object
#  8   Category_1            63505 non-null  object
#  9   highlight             50131 non-null  object
#  10  Category2_URL_search  59889 non-null  object
#  11  Category_2            59889 non-null  object
#  12  Category3_URL_search  54997 non-null  object
#  13  Category_3            54997 non-null  object
#  14  Category4_URL_search  47543 non-null  object
# ...

# %%
df.drop('Job_URL',axis=1,inplace=True)
df.drop('Posted_from',axis=1,inplace=True)
df.drop('Category1_URL_search',axis=1,inplace=True)
df.drop('highlight',axis=1,inplace=True)
df.drop('Category2_URL_search',axis=1,inplace=True)
df.drop('Category3_URL_search',axis=1,inplace=True)
df.drop('Category4_URL_search',axis=1,inplace=True)
df.drop('Category5_URL_search',axis=1,inplace=True)
df.drop('Category6_URL_search',axis=1,inplace=True)
df.drop('Category7_URL_search',axis=1,inplace=True)
df.drop('Category8_URL_search',axis=1,inplace=True)
df.drop('Category9_URL_search',axis=1,inplace=True)
df.drop('Enterprise_Client',axis=1,inplace=True)
df.drop('Freelancers_Num',axis=1,inplace=True)
df.drop('Feedback_Num',axis=1,inplace=True)
df.drop('Start_rate',axis=1,inplace=True)
df.drop('End_rate',axis=1,inplace=True)

# %%
df.head()
# Out:
#                                            Job Title EX_level_demand  \
# 0                      Power bi specialist freelance          Expert
# 1            Case Study (on-demand delivery startup)    Intermediate
# 2  File Maker Pro Reports, Charts, Query and Ongo...    Intermediate
# 3          Implementation of EleutherAI/gpt-neox-20b          Expert
# 4  BI and Data Engineer for Upwork Finance System...          Expert
#
#                         Time_Limitation Search_Keyword  \
# 0                                   NaN   Data_science
# 1                                   NaN   Data_science
# 2  3 to 6 months, Less than 30 hrs/week   Data_science
# 3  3 to 6 months, Less than 30 hrs/week   Data_science
# 4      More than 6 months, 30+ hrs/week   Data_science
#
#                                          Description              Category_1  \
# 0  Already data pooled and designed. Need to refi...           Data Analysis
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63950 entries, 0 to 63949
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          63949 non-null  object
#  1   EX_level_demand    56935 non-null  object
#  2   Time_Limitation    23034 non-null  object
#  3   Search_Keyword     63949 non-null  object
#  4   Description        63948 non-null  object
#  5   Category_1         63505 non-null  object
#  6   Category_2         59889 non-null  object
#  7   Category_3         54997 non-null  object
#  8   Category_4         47543 non-null  object
#  9   Category_5         39578 non-null  object
#  10  Category_6         31307 non-null  object
#  11  Category_7         25192 non-null  object
#  12  Category_8         20436 non-null  object
#  13  Category_9         16481 non-null  object
#  14  Applicants_Num     63949 non-null  object
#  15  Payment_Situation  63949 non-null  object
# ...

# %%
duplicates=df.duplicated(subset=['Job Title'],keep=False)
print(df[duplicates])
# Out:
#                                                Job Title EX_level_demand  \
# 8                          Azure Data Factory specialist    Intermediate
# 17     Programmer and expert training AI models (tens...          Expert
# 19                                          Excel expert     Entry level
# 20     Searching for data engineer to build AWS Glue ...          Expert
# 27                             Machine Learning Engineer    Intermediate
# ...                                                  ...             ...
# 63933                            Facebook ads specialist          Expert
# 63934  Project manager for a music marketing startup ...          Expert
# 63939  YouTube SEO and  Organic Growth Experts Needed...     Entry level
# 63943  Social media pro to write and post to Instagra...    Intermediate
# 63944                             Email Marketing Expert          Expert
#
#                             Time_Limitation Search_Keyword  \
# ...

# %%
df.drop_duplicates(subset=['Job Title'],keep='first',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54909 entries, 0 to 63949
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          54908 non-null  object
#  1   EX_level_demand    50529 non-null  object
#  2   Time_Limitation    20396 non-null  object
#  3   Search_Keyword     54908 non-null  object
#  4   Description        54907 non-null  object
#  5   Category_1         54509 non-null  object
#  6   Category_2         51419 non-null  object
#  7   Category_3         47117 non-null  object
#  8   Category_4         40636 non-null  object
#  9   Category_5         33780 non-null  object
#  10  Category_6         26580 non-null  object
#  11  Category_7         21320 non-null  object
#  12  Category_8         17251 non-null  object
#  13  Category_9         13850 non-null  object
#  14  Applicants_Num     54908 non-null  object
#  15  Payment_Situation  54908 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Job Title                1
# EX_level_demand       4380
# Time_Limitation      34513
# Search_Keyword           1
# Description              2
# Category_1             400
# Category_2            3490
# Category_3            7792
# Category_4           14273
# Category_5           21129
# Category_6           28329
# Category_7           33589
# Category_8           37658
# Category_9           41059
# Applicants_Num           1
# Payment_Situation        1
# Spent($)              1377
# Client_Country         114
# Connects_Num             1
# New_Connects_Num         1
# Rating               28011
# Payment_type             1
# Job_Cost             37811
# Hourly_Rate          32170
# dtype: int64

# %%
null=df.isna().any(axis=1)
nullr=df[null]
nullr=df[df['Job Title'].isnull()]
nullr
# Out:
#       Job Title EX_level_demand Time_Limitation Search_Keyword Description  \
# 63949       NaN             NaN             NaN            NaN         NaN
#
#       Category_1 Category_2 Category_3 Category_4 Category_5  ...  \
# 63949        NaN        NaN        NaN        NaN        NaN  ...
#
#       Applicants_Num Payment_Situation Spent($) Client_Country Connects_Num  \
# 63949            NaN               NaN      NaN            NaN          NaN
#
#       New_Connects_Num  Rating Payment_type  Job_Cost  Hourly_Rate
# 63949              NaN     NaN          NaN       NaN          NaN
#
# [1 rows x 24 columns]

# %%
df=df.drop(63949)

# %%
df.isnull().sum()
# Out:
# Job Title                0
# EX_level_demand       4379
# Time_Limitation      34512
# Search_Keyword           0
# Description              1
# Category_1             399
# Category_2            3489
# Category_3            7791
# Category_4           14272
# Category_5           21128
# Category_6           28328
# Category_7           33588
# Category_8           37657
# Category_9           41058
# Applicants_Num           0
# Payment_Situation        0
# Spent($)              1376
# Client_Country         113
# Connects_Num             0
# New_Connects_Num         0
# Rating               28010
# Payment_type             0
# Job_Cost             37810
# Hourly_Rate          32169
# dtype: int64

# %%
null=df.isna().any(axis=1)
nullr=df[null]
nullr=df[df['Description'].isnull()]
nullr
# Out:
#                                Job Title EX_level_demand  \
# 1498  Good Flutter and Django Developer.    Intermediate
#
#                                Time_Limitation Search_Keyword Description  \
# 1498  Less than 1 month, Less than 30 hrs/week   Data_science         NaN
#
#         Category_1 Category_2                Category_3 Category_4  \
# 1498  Data Science     Python  Firebase Cloud Firestore       Dart
#
#                   Category_5  ... Applicants_Num   Payment_Situation Spent($)  \
# 1498  Mobile App Development  ...        5 to 10  Payment unverified      0.0
#
#      Client_Country Connects_Num New_Connects_Num  Rating Payment_type  \
# 1498        Ireland          1.0              2.0     NaN       Hourly
#
#       Job_Cost  Hourly_Rate
# 1498       NaN          NaN
#
# [1 rows x 24 columns]

# %%
df=df.drop(1498)

# %%
df.isnull().sum()
# Out:
# Job Title                0
# EX_level_demand       4379
# Time_Limitation      34512
# Search_Keyword           0
# Description              0
# Category_1             399
# Category_2            3489
# Category_3            7791
# Category_4           14272
# Category_5           21128
# Category_6           28328
# Category_7           33588
# Category_8           37657
# Category_9           41058
# Applicants_Num           0
# Payment_Situation        0
# Spent($)              1376
# Client_Country         113
# Connects_Num             0
# New_Connects_Num         0
# Rating               28009
# Payment_type             0
# Job_Cost             37809
# Hourly_Rate          32168
# dtype: int64

# %%
df['EX_level_demand']=df['EX_level_demand'].fillna('Missing')
df['Time_Limitation']=df['Time_Limitation'].fillna('Missing')
df['Category_1']=df['Category_1'].fillna('Missing')
df['Category_2']=df['Category_2'].fillna('Missing')
df['Category_3']=df['Category_3'].fillna('Missing')
df['Category_4']=df['Category_4'].fillna('Missing')
df['Category_5']=df['Category_5'].fillna('Missing')
df['Category_6']=df['Category_6'].fillna('Missing')
df['Category_7']=df['Category_7'].fillna('Missing')
df['Category_8']=df['Category_8'].fillna('Missing')
df['Category_9']=df['Category_9'].fillna('Missing')
df['Spent($)']=df['Spent($)'].fillna(0.0)
df['Client_Country']=df['Client_Country'].fillna('Missing')
df['Rating']=df['Rating'].fillna(0.0)
df['Job_Cost']=df['Job_Cost'].fillna('Missing')
df['Hourly_Rate']=df['Hourly_Rate'].fillna('Missing')
df.isnull().sum()
# Out:
# Job Title            0
# EX_level_demand      0
# Time_Limitation      0
# Search_Keyword       0
# Description          0
# Category_1           0
# Category_2           0
# Category_3           0
# Category_4           0
# Category_5           0
# Category_6           0
# Category_7           0
# Category_8           0
# Category_9           0
# Applicants_Num       0
# Payment_Situation    0
# Spent($)             0
# Client_Country       0
# Connects_Num         0
# New_Connects_Num     0
# Rating               0
# Payment_type         0
# Job_Cost             0
# Hourly_Rate          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54907 entries, 0 to 63948
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          54907 non-null  object
#  1   EX_level_demand    54907 non-null  object
#  2   Time_Limitation    54907 non-null  object
#  3   Search_Keyword     54907 non-null  object
#  4   Description        54907 non-null  object
#  5   Category_1         54907 non-null  object
#  6   Category_2         54907 non-null  object
#  7   Category_3         54907 non-null  object
#  8   Category_4         54907 non-null  object
#  9   Category_5         54907 non-null  object
#  10  Category_6         54907 non-null  object
#  11  Category_7         54907 non-null  object
#  12  Category_8         54907 non-null  object
#  13  Category_9         54907 non-null  object
#  14  Applicants_Num     54907 non-null  object
#  15  Payment_Situation  54907 non-null  object
# ...

# %%
df.to_csv('Cleaning_Final_Upwork.csv')
